# %% [markdown]
# 第一個jupyter程式測試

# %%
a="1"
X="2"
a+X
# Out:
# '12'

# %%
aa=2
xx=3
aa+xx
# Out:
# 5

# %%
第二個jupyter程式特測試ˇ

# %%
Y="CYY"
an="3"
a+X+an+Y
# Out:
# '123CYY'

# %% [markdown]
# 3行寫出 尋找指定網頁的原始碼

# %%
import requests
c=requests.get("http://www.yahoo.com.tw")
print(c.text)
# Out:
# <!DOCTYPE html>
# <html id="Stencil" lang="zh-Hant-TW" class="StencilRoot  my3columns  l-out Pos-r https fp fp-default ltr desktop Desktop bkt900">
# <head>
#
# ...
